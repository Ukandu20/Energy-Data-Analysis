# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio

# %%
missing__data = df_cleaned_data[df_cleaned_data['Access to clean fuels for cooking'].isnull()]


# Display the rows with missing data
print("Rows with missing fossil fuel data:")
display(missing__data[['Entity', 'Year', 'Access to clean fuels for cooking']])

df_cleaned_data['Access to clean fuels for cooking'] = df_cleaned_data['Access to clean fuels for cooking'].fillna(0)

print(df_cleaned_data['Access to clean fuels for cooking'].isnull().sum())
# Out:
# Rows with missing fossil fuel data:
# Empty DataFrame
# Columns: [Entity, Year, Access to clean fuels for cooking]
# Index: []
# 0

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['gdp_per_capita'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'gdp_per_capita'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_per_capita = df_cleaned_data.groupby('Entity')['gdp_per_capita'].transform('mean')
df_cleaned_data['gdp_per_capita'] = df_cleaned_data['gdp_per_capita'].fillna(mean_gdp_per_capita)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['gdp_per_capita'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'gdp_per_capita']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  gdp_per_capita
# 0     Afghanistan  2000      439.055765
# 1     Afghanistan  2001      439.055765
# 2     Afghanistan  2002      179.426579
# 3     Afghanistan  2003      190.683814
# 4     Afghanistan  2004      211.382074
# ...           ...   ...             ...
# 3644     Zimbabwe  2016     1464.588957
# 3645     Zimbabwe  2017     1235.189032
# 3646     Zimbabwe  2018     1254.642265
# 3647     Zimbabwe  2019     1316.740657
# 3648     Zimbabwe  2020     1214.509820
#
# [3648 rows x 3 columns]

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['gdp_per_capita'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'gdp_per_capita'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_per_capita = df_cleaned_data.groupby('Entity')['gdp_per_capita'].transform('mean')
df_cleaned_data['gdp_per_capita'] = df_cleaned_data['gdp_per_capita'].fillna(mean_gdp_per_capita)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['gdp_per_capita'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'gdp_per_capita']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  gdp_per_capita
# 0     Afghanistan  2000      439.055765
# 1     Afghanistan  2001      439.055765
# 2     Afghanistan  2002      179.426579
# 3     Afghanistan  2003      190.683814
# 4     Afghanistan  2004      211.382074
# ...           ...   ...             ...
# 3644     Zimbabwe  2016     1464.588957
# 3645     Zimbabwe  2017     1235.189032
# 3646     Zimbabwe  2018     1254.642265
# 3647     Zimbabwe  2019     1316.740657
# 3648     Zimbabwe  2020     1214.509820
#
# [3648 rows x 3 columns]

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['gdp_growth'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'gdp_growth'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_growth = df_cleaned_data.groupby('Entity')['gdp_growth'].transform('mean')
df_cleaned_data['gdp_growth'] = df_cleaned_data['gdp_growth'].fillna(mean_gdp_growth)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['gdp_growth'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'gdp_growth']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  gdp_growth
# 0     Afghanistan  2000    6.163893
# 1     Afghanistan  2001    6.163893
# 2     Afghanistan  2002    6.163893
# 3     Afghanistan  2003    8.832278
# 4     Afghanistan  2004    1.414118
# ...           ...   ...         ...
# 3644     Zimbabwe  2016    0.755869
# 3645     Zimbabwe  2017    4.709492
# 3646     Zimbabwe  2018    4.824211
# 3647     Zimbabwe  2019   -6.144236
# 3648     Zimbabwe  2020   -6.248748
#
# [3648 rows x 3 columns]

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['Renewable energy share in the total final energy consumption (%)'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'Renewable energy share in the total final energy consumption (%)'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_growth = df_cleaned_data.groupby('Entity')['Renewable energy share in the total final energy consumption (%)'].transform('mean')
df_cleaned_data['Renewable energy share in the total final energy consumption (%)'] = df_cleaned_data['Renewable energy share in the total final energy consumption (%)'].fillna(mean_gdp_growth)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['Renewable energy share in the total final energy consumption (%)'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'Renewable energy share in the total final energy consumption (%)']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 3644     Zimbabwe  2016
# 3645     Zimbabwe  2017
# 3646     Zimbabwe  2018
# 3647     Zimbabwe  2019
# 3648     Zimbabwe  2020
#
#       Renewable energy share in the total final energy consumption (%)
# 0                                                 44.99
# 1                                                 45.60
# 2                                                 37.83
# 3                                                 36.66
# 4                                                 44.24
# ...                                                 ...
# 3644                                              81.90
# 3645                                              82.46
# 3646                                              80.23
# ...

# %%
#missing__data = df_cleaned_data[df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].isnull()]


# Display the rows with missing data
#print("Rows with missing fossil fuel data:")
#with pd.option_context('display.max_colwidth', None,
#                       'display.max_columns', None,
#                       'display.max_rows', None):
#    display(missing__data[['Entity', 'Year', 'Energy intensity level of primary energy (MJ/$2017 PPP GDP)']])

#df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'] = df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].fillna(0)

#print(df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].isnull().sum())

# %%
with pd.option_context('display.max_colwidth', None,
                       'display.max_columns', None,
                     'display.max_rows', None):
    print(df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].value_counts())
# Out:
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)
# 5.150000     15
# 3.070000     15
# 3.860000     14
# 3.180000     14
# 2.970000     14
# 4.280000     13
# 2.680000     13
# 2.640000     12
# 3.880000     12
# 3.870000     12
# 3.470000     12
# 3.270000     12
# 3.570000     12
# 3.590000     12
# 3.970000     12
# 3.440000     12
# 3.900000     12
# 3.980000     12
# 3.890000     12
# 3.800000     12
# 5.660000     11
# 2.940000     11
# 3.330000     11
# 3.030000     11
# 2.480000     11
# 3.550000     11
# 3.120000     11
# 3.060000     11
# 2.530000     11
# 4.470000     11
# 5.000000     11
# 3.310000     11
# 5.280000     11
# 2.890000     11
# 2.830000     10
# 3.660000     10
# 3.390000     10
# 4.300000     10
# 5.100000     10
# 3.360000     10
# 3.680000     10
# 3.490000     10
# 2.580000     10
# 2.880000     10
# 3.400000     10
# 3.850000     10
# 4.010000     10
# 2.500000     10
# 3.340000     10
# 5.230000     10
# 2.860000     10
# 2.710000     10
# ...

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'Energy intensity level of primary energy (MJ/$2017 PPP GDP)'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_growth = df_cleaned_data.groupby('Entity')['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].transform('mean')
df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'] = df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].fillna(mean_gdp_growth)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'Energy intensity level of primary energy (MJ/$2017 PPP GDP)']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 3644     Zimbabwe  2016
# 3645     Zimbabwe  2017
# 3646     Zimbabwe  2018
# 3647     Zimbabwe  2019
# 3648     Zimbabwe  2020
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)
# 0                                                  1.64
# 1                                                  1.74
# 2                                                  1.40
# 3                                                  1.40
# 4                                                  1.20
# ...                                                 ...
# 3644                                              10.00
# 3645                                               9.51
# 3646                                               9.83
# ...

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['Value_co2_emissions_kt_by_country'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'Value_co2_emissions_kt_by_country'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_growth = df_cleaned_data.groupby('Entity')['Value_co2_emissions_kt_by_country'].transform('mean')
df_cleaned_data['Value_co2_emissions_kt_by_country'] = df_cleaned_data['Value_co2_emissions_kt_by_country'].fillna(mean_gdp_growth)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['Value_co2_emissions_kt_by_country'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'Value_co2_emissions_kt_by_country']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  Value_co2_emissions_kt_by_country
# 0     Afghanistan  2000                         760.000000
# 1     Afghanistan  2001                         730.000000
# 2     Afghanistan  2002                        1029.999971
# 3     Afghanistan  2003                        1220.000029
# 4     Afghanistan  2004                        1029.999971
# ...           ...   ...                                ...
# 3644     Zimbabwe  2016                       11020.000460
# 3645     Zimbabwe  2017                       10340.000150
# 3646     Zimbabwe  2018                       12380.000110
# 3647     Zimbabwe  2019                       11760.000230
# 3648     Zimbabwe  2020                       11040.000110
#
# [3648 rows x 3 columns]

# %%
# Identify countries where all GDP per capita data is missing
countries_with_no_gdp = df_cleaned_data.groupby('Entity')['Renewable-electricity-generating-capacity-per-capita'].transform(lambda x: x.isnull().all())

# Replace GDP per capita with 0 for countries that have no GDP data at all
df_cleaned_data.loc[countries_with_no_gdp, 'Renewable-electricity-generating-capacity-per-capita'] = 0

# Replace remaining missing GDP per capita values with the mean GDP per capita for each country
mean_gdp_growth = df_cleaned_data.groupby('Entity')['Renewable-electricity-generating-capacity-per-capita'].transform('mean')
df_cleaned_data['Renewable-electricity-generating-capacity-per-capita'] = df_cleaned_data['Renewable-electricity-generating-capacity-per-capita'].fillna(mean_gdp_growth)

# Verify that missing values have been replaced
print("Remaining missing GDP per capita values:", df_cleaned_data['Renewable-electricity-generating-capacity-per-capita'].isnull().sum())

# Optional: Display updated rows
print("Updated GDP per capita data:")
display(df_cleaned_data[['Entity', 'Year', 'Renewable-electricity-generating-capacity-per-capita']])
# Out:
# Remaining missing GDP per capita values: 0
# Updated GDP per capita data:
#            Entity  Year  Renewable-electricity-generating-capacity-per-capita
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# ...

# %%
print(df_cleaned_data.isnull().sum())
# Out:
# Entity                                                              0
# Year                                                                0
# Access to electricity (% of population)                             0
# Access to clean fuels for cooking                                   0
# Renewable-electricity-generating-capacity-per-capita                0
# Financial flows to developing countries (US $)                      0
# Renewable energy share in the total final energy consumption (%)    0
# Electricity from fossil fuels (TWh)                                 0
# Electricity from nuclear (TWh)                                      0
# Electricity from renewables (TWh)                                   0
# Low-carbon electricity (% electricity)                              0
# Primary energy consumption per capita (kWh/person)                  0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)         0
# ...
